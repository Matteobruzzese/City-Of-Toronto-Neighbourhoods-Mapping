# %%
##This code cell is a slight modification of the Vader Sentiment analysis tool found at :
##https://github.com/cjhutto/vaderSentiment


##Reference:
##Hutto, C.J. & Gilbert, E.E. (2014). VADER: A Parsimonious Rule-based Model for Sentiment Analysis of Social Media Text. Eighth International Conference on Weblogs and Social Media (ICWSM-14). Ann Arbor, MI, June 2014.

import os
import re
import math
import string
import requests
import json
from itertools import product
from inspect import getsourcefile
from io import open

# ##Constants##

# (empirically derived mean sentiment intensity rating increase for booster words)
B_INCR = 0.293
B_DECR = -0.293

# (empirically derived mean sentiment intensity rating increase for using ALLCAPs to emphasize a word)
C_INCR = 0.733
N_SCALAR = -0.74

# for removing punctuation
REGEX_REMOVE_PUNCTUATION = re.compile('[%s]' % re.escape(string.punctuation))

PUNC_LIST = [".", "!", "?", ",", ";", ":", "-", "'", "\"",
             "!!", "!!!", "??", "???", "?!?", "!?!", "?!?!", "!?!?"]
NEGATE = \
    ["aint", "arent", "cannot", "cant", "couldnt", "darent", "didnt", "doesnt",
     "ain't", "aren't", "can't", "couldn't", "daren't", "didn't", "doesn't",
     "dont", "hadnt", "hasnt", "havent", "isnt", "mightnt", "mustnt", "neither",
     "don't", "hadn't", "hasn't", "haven't", "isn't", "mightn't", "mustn't",
     "neednt", "needn't", "never", "none", "nope", "nor", "not", "nothing", "nowhere",
     "oughtnt", "shant", "shouldnt", "uhuh", "wasnt", "werent",
     "oughtn't", "shan't", "shouldn't", "uh-uh", "wasn't", "weren't",
     "without", "wont", "wouldnt", "won't", "wouldn't", "rarely", "seldom", "despite"]

# booster/dampener 'intensifiers' or 'degree adverbs'
# http://en.wiktionary.org/wiki/Category:English_degree_adverbs

BOOSTER_DICT = \
    {"absolutely": B_INCR, "amazingly": B_INCR, "awfully": B_INCR, "completely": B_INCR, "considerably": B_INCR,
     "decidedly": B_INCR, "deeply": B_INCR, "effing": B_INCR, "enormously": B_INCR,
     "entirely": B_INCR, "especially": B_INCR, "exceptionally": B_INCR, "extremely": B_INCR,
     "fabulously": B_INCR, "flipping": B_INCR, "flippin": B_INCR,
     "fricking": B_INCR, "frickin": B_INCR, "frigging": B_INCR, "friggin": B_INCR, "fully": B_INCR, "fucking": B_INCR,
     "greatly": B_INCR, "hella": B_INCR, "highly": B_INCR, "hugely": B_INCR, "incredibly": B_INCR,
     "intensely": B_INCR, "majorly": B_INCR, "more": B_INCR, "most": B_INCR, "particularly": B_INCR,
     "purely": B_INCR, "quite": B_INCR, "really": B_INCR, "remarkably": B_INCR,
     "so": B_INCR, "substantially": B_INCR,
     "thoroughly": B_INCR, "totally": B_INCR, "tremendously": B_INCR,
     "uber": B_INCR, "unbelievably": B_INCR, "unusually": B_INCR, "utterly": B_INCR,
     "very": B_INCR,
     "almost": B_DECR, "barely": B_DECR, "hardly": B_DECR, "just enough": B_DECR,
     "kind of": B_DECR, "kinda": B_DECR, "kindof": B_DECR, "kind-of": B_DECR,
     "less": B_DECR, "little": B_DECR, "marginally": B_DECR, "occasionally": B_DECR, "partly": B_DECR,
     "scarcely": B_DECR, "slightly": B_DECR, "somewhat": B_DECR,
     "sort of": B_DECR, "sorta": B_DECR, "sortof": B_DECR, "sort-of": B_DECR}

# check for sentiment laden idioms that do not contain lexicon words (future work, not yet implemented)
SENTIMENT_LADEN_IDIOMS = {"cut the mustard": 2, "hand to mouth": -2,
                          "back handed": -2, "blow smoke": -2, "blowing smoke": -2,
                          "upper hand": 1, "break a leg": 2,
                          "cooking with gas": 2, "in the black": 2, "in the red": -2,
                          "on the ball": 2, "under the weather": -2}

# check for special case idioms containing lexicon words
SPECIAL_CASE_IDIOMS = {"the shit": 3, "the bomb": 3, "bad ass": 1.5, "yeah right": -2,
                       "kiss of death": -1.5}


# #Static methods# #

def negated(input_words, include_nt=True):
    """
    Determine if input contains negation words
    """
    input_words = [str(w).lower() for w in input_words]
    neg_words = []
    neg_words.extend(NEGATE)
    for word in neg_words:
        if word in input_words:
            return True
    if include_nt:
        for word in input_words:
            if "n't" in word:
                return True
    if "least" in input_words:
        i = input_words.index("least")
        if i > 0 and input_words[i - 1] != "at":
            return True
    return False


def normalize(score, alpha=15):
    """
    Normalize the score to be between -1 and 1 using an alpha that
    approximates the max expected value
    """
    norm_score = score / math.sqrt((score * score) + alpha)
    if norm_score < -1.0:
        return -1.0
    elif norm_score > 1.0:
        return 1.0
    else:
        return norm_score


def allcap_differential(words):
    """
    Check whether just some words in the input are ALL CAPS
    :param list words: The words to inspect
    :returns: `True` if some but not all items in `words` are ALL CAPS
    """
    is_different = False
    allcap_words = 0
    for word in words:
        if word.isupper():
            allcap_words += 1
    cap_differential = len(words) - allcap_words
    if 0 < cap_differential < len(words):
        is_different = True
    return is_different


def scalar_inc_dec(word, valence, is_cap_diff):
    """
    Check if the preceding words increase, decrease, or negate/nullify the
    valence
    """
    scalar = 0.0
    word_lower = word.lower()
    if word_lower in BOOSTER_DICT:
        scalar = BOOSTER_DICT[word_lower]
        if valence < 0:
            scalar *= -1
        # check if booster/dampener word is in ALLCAPS (while others aren't)
        if word.isupper() and is_cap_diff:
            if valence > 0:
                scalar += C_INCR
            else:
                scalar -= C_INCR
    return scalar


class SentiText(object):
    """
    Identify sentiment-relevant string-level properties of input text.
    """

    def __init__(self, text):
        if not isinstance(text, str):
            text = str(text).encode('utf-8')
        self.text = text
        self.words_and_emoticons = self._words_and_emoticons()
        # doesn't separate words from\
        # adjacent punctuation (keeps emoticons & contractions)
        self.is_cap_diff = allcap_differential(self.words_and_emoticons)

    def _words_plus_punc(self):
        """
        Returns mapping of form:
        {
            'cat,': 'cat',
            ',cat': 'cat',
        }
        """
        no_punc_text = REGEX_REMOVE_PUNCTUATION.sub('', self.text)
        # removes punctuation (but loses emoticons & contractions)
        words_only = no_punc_text.split()
        # remove singletons
        words_only = set(w for w in words_only if len(w) > 1)
        # the product gives ('cat', ',') and (',', 'cat')
        punc_before = {''.join(p): p[1] for p in product(PUNC_LIST, words_only)}
        punc_after = {''.join(p): p[0] for p in product(words_only, PUNC_LIST)}
        words_punc_dict = punc_before
        words_punc_dict.update(punc_after)
        return words_punc_dict

    def _words_and_emoticons(self):
        """
        Removes leading and trailing puncutation
        Leaves contractions and most emoticons
            Does not preserve punc-plus-letter emoticons (e.g. :D)
        """
        wes = self.text.split()
        words_punc_dict = self._words_plus_punc()
        wes = [we for we in wes if len(we) > 1]
        for i, we in enumerate(wes):
            if we in words_punc_dict:
                wes[i] = words_punc_dict[we]
        return wes


class SentimentIntensityAnalyzer(object):
    """
    Give a sentiment intensity score to sentences.
    """

    def __init__(self, lexicon_file="vader_lexicon.txt", emoji_lexicon="emoji_utf8_lexicon.txt"):
        _this_module_file_path_ = os.path.abspath(getsourcefile(lambda: 0))
        lexicon_full_filepath = os.path.join(os.path.dirname(_this_module_file_path_), lexicon_file)
        with open(lexicon_full_filepath, encoding='utf-8') as f:
            self.lexicon_full_filepath = f.read()
        self.lexicon = self.make_lex_dict()

        emoji_full_filepath = os.path.join(os.path.dirname(_this_module_file_path_), emoji_lexicon)
        with open(emoji_full_filepath, encoding='utf-8') as f:
            self.emoji_full_filepath = f.read()
        self.emojis = self.make_emoji_dict()

    def make_lex_dict(self):
        """
        Convert lexicon file to a dictionary
        """
        lex_dict = {}
        for line in self.lexicon_full_filepath.split('\n'):
            (word, measure) = line.strip().split('\t')[0:2]
            lex_dict[word] = float(measure)
        return lex_dict

    def make_emoji_dict(self):
        """
        Convert emoji lexicon file to a dictionary
        """
        emoji_dict = {}
        for line in self.emoji_full_filepath.split('\n'):
            (emoji, description) = line.strip().split('\t')[0:2]
            emoji_dict[emoji] = description
        return emoji_dict

    def polarity_scores(self, text):
        """
        Return a float for sentiment strength based on the input text.
        Positive values are positive valence, negative value are negative
        valence.
        """
        # convert emojis to their textual descriptions
        text_token_list = text.split()
        text_no_emoji_lst = []
        for token in text_token_list:
            if token in self.emojis:
                # get the textual description
                description = self.emojis[token]
                text_no_emoji_lst.append(description)
            else:
                text_no_emoji_lst.append(token)
        text = " ".join(x for x in text_no_emoji_lst)

        sentitext = SentiText(text)

        sentiments = []
        words_and_emoticons = sentitext.words_and_emoticons
        for item in words_and_emoticons:
            valence = 0
            i = words_and_emoticons.index(item)
            # check for vader_lexicon words that may be used as modifiers or negations
            if item.lower() in BOOSTER_DICT:
                sentiments.append(valence)
                continue
            if (i < len(words_and_emoticons) - 1 and item.lower() == "kind" and
                    words_and_emoticons[i + 1].lower() == "of"):
                sentiments.append(valence)
                continue

            sentiments = self.sentiment_valence(valence, sentitext, item, i, sentiments)

        sentiments = self._but_check(words_and_emoticons, sentiments)

        valence_dict = self.score_valence(sentiments, text)

        return valence_dict

    def sentiment_valence(self, valence, sentitext, item, i, sentiments):
        is_cap_diff = sentitext.is_cap_diff
        words_and_emoticons = sentitext.words_and_emoticons
        item_lowercase = item.lower()
        if item_lowercase in self.lexicon:
            # get the sentiment valence
            valence = self.lexicon[item_lowercase]
            # check if sentiment laden word is in ALL CAPS (while others aren't)
            if item.isupper() and is_cap_diff:
                if valence > 0:
                    valence += C_INCR
                else:
                    valence -= C_INCR

            for start_i in range(0, 3):
                # dampen the scalar modifier of preceding words and emoticons
                # (excluding the ones that immediately preceed the item) based
                # on their distance from the current item.
                if i > start_i and words_and_emoticons[i - (start_i + 1)].lower() not in self.lexicon:
                    s = scalar_inc_dec(words_and_emoticons[i - (start_i + 1)], valence, is_cap_diff)
                    if start_i == 1 and s != 0:
                        s = s * 0.95
                    if start_i == 2 and s != 0:
                        s = s * 0.9
                    valence = valence + s
                    valence = self._negation_check(valence, words_and_emoticons, start_i, i)
                    if start_i == 2:
                        valence = self._special_idioms_check(valence, words_and_emoticons, i)

            valence = self._least_check(valence, words_and_emoticons, i)
        sentiments.append(valence)
        return sentiments

    def _least_check(self, valence, words_and_emoticons, i):
        # check for negation case using "least"
        if i > 1 and words_and_emoticons[i - 1].lower() not in self.lexicon \
                and words_and_emoticons[i - 1].lower() == "least":
            if words_and_emoticons[i - 2].lower() != "at" and words_and_emoticons[i - 2].lower() != "very":
                valence = valence * N_SCALAR
        elif i > 0 and words_and_emoticons[i - 1].lower() not in self.lexicon \
                and words_and_emoticons[i - 1].lower() == "least":
            valence = valence * N_SCALAR
        return valence

    @staticmethod
    def _but_check(words_and_emoticons, sentiments):
        # check for modification in sentiment due to contrastive conjunction 'but'
        words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
        if 'but' in words_and_emoticons_lower:
            bi = words_and_emoticons_lower.index('but')
            for sentiment in sentiments:
                si = sentiments.index(sentiment)
                if si < bi:
                    sentiments.pop(si)
                    sentiments.insert(si, sentiment * 0.5)
                elif si > bi:
                    sentiments.pop(si)
                    sentiments.insert(si, sentiment * 1.5)
        return sentiments

    @staticmethod
    def _special_idioms_check(valence, words_and_emoticons, i):
        words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
        onezero = "{0} {1}".format(words_and_emoticons_lower[i - 1], words_and_emoticons_lower[i])

        twoonezero = "{0} {1} {2}".format(words_and_emoticons_lower[i - 2],
                                          words_and_emoticons_lower[i - 1], words_and_emoticons_lower[i])

        twoone = "{0} {1}".format(words_and_emoticons_lower[i - 2], words_and_emoticons_lower[i - 1])

        threetwoone = "{0} {1} {2}".format(words_and_emoticons_lower[i - 3],
                                           words_and_emoticons_lower[i - 2], words_and_emoticons_lower[i - 1])

        threetwo = "{0} {1}".format(words_and_emoticons_lower[i - 3], words_and_emoticons_lower[i - 2])

        sequences = [onezero, twoonezero, twoone, threetwoone, threetwo]

        for seq in sequences:
            if seq in SPECIAL_CASE_IDIOMS:
                valence = SPECIAL_CASE_IDIOMS[seq]
                break

        if len(words_and_emoticons_lower) - 1 > i:
            zeroone = "{0} {1}".format(words_and_emoticons_lower[i], words_and_emoticons_lower[i + 1])
            if zeroone in SPECIAL_CASE_IDIOMS:
                valence = SPECIAL_CASE_IDIOMS[zeroone]
        if len(words_and_emoticons_lower) - 1 > i + 1:
            zeroonetwo = "{0} {1} {2}".format(words_and_emoticons_lower[i], words_and_emoticons_lower[i + 1],
                                              words_and_emoticons_lower[i + 2])
            if zeroonetwo in SPECIAL_CASE_IDIOMS:
                valence = SPECIAL_CASE_IDIOMS[zeroonetwo]

        # check for booster/dampener bi-grams such as 'sort of' or 'kind of'
        n_grams = [threetwoone, threetwo, twoone]
        for n_gram in n_grams:
            if n_gram in BOOSTER_DICT:
                valence = valence + BOOSTER_DICT[n_gram]
        return valence

    @staticmethod
    def _sentiment_laden_idioms_check(valence, senti_text_lower):
        # Future Work
        # check for sentiment laden idioms that don't contain a lexicon word
        idioms_valences = []
        for idiom in SENTIMENT_LADEN_IDIOMS:
            if idiom in senti_text_lower:
                print(idiom, senti_text_lower)
                valence = SENTIMENT_LADEN_IDIOMS[idiom]
                idioms_valences.append(valence)
        if len(idioms_valences) > 0:
            valence = sum(idioms_valences) / float(len(idioms_valences))
        return valence

    @staticmethod
    def _negation_check(valence, words_and_emoticons, start_i, i):
        words_and_emoticons_lower = [str(w).lower() for w in words_and_emoticons]
        if start_i == 0:
            if negated([words_and_emoticons_lower[i - (start_i + 1)]]):  # 1 word preceding lexicon word (w/o stopwords)
                valence = valence * N_SCALAR
        if start_i == 1:
            if words_and_emoticons_lower[i - 2] == "never" and \
                    (words_and_emoticons_lower[i - 1] == "so" or
                     words_and_emoticons_lower[i - 1] == "this"):
                valence = valence * 1.25
            elif words_and_emoticons_lower[i - 2] == "without" and \
                    words_and_emoticons_lower[i - 1] == "doubt":
                valence = valence
            elif negated([words_and_emoticons_lower[i - (start_i + 1)]]):  # 2 words preceding the lexicon word position
                valence = valence * N_SCALAR
        if start_i == 2:
            if words_and_emoticons_lower[i - 3] == "never" and \
                    (words_and_emoticons_lower[i - 2] == "so" or words_and_emoticons_lower[i - 2] == "this") or \
                    (words_and_emoticons_lower[i - 1] == "so" or words_and_emoticons_lower[i - 1] == "this"):
                valence = valence * 1.25
            elif words_and_emoticons_lower[i - 3] == "without" and \
                    (words_and_emoticons_lower[i - 2] == "doubt" or words_and_emoticons_lower[i - 1] == "doubt"):
                valence = valence
            elif negated([words_and_emoticons_lower[i - (start_i + 1)]]):  # 3 words preceding the lexicon word position
                valence = valence * N_SCALAR
        return valence

    def _punctuation_emphasis(self, text):
        # add emphasis from exclamation points and question marks
        ep_amplifier = self._amplify_ep(text)
        qm_amplifier = self._amplify_qm(text)
        punct_emph_amplifier = ep_amplifier + qm_amplifier
        return punct_emph_amplifier

    @staticmethod
    def _amplify_ep(text):
        # check for added emphasis resulting from exclamation points (up to 4 of them)
        ep_count = text.count("!")
        if ep_count > 4:
            ep_count = 4
        # (empirically derived mean sentiment intensity rating increase for
        # exclamation points)
        ep_amplifier = ep_count * 0.292
        return ep_amplifier

    @staticmethod
    def _amplify_qm(text):
        # check for added emphasis resulting from question marks (2 or 3+)
        qm_count = text.count("?")
        qm_amplifier = 0
        if qm_count > 1:
            if qm_count <= 3:
                # (empirically derived mean sentiment intensity rating increase for
                # question marks)
                qm_amplifier = qm_count * 0.18
            else:
                qm_amplifier = 0.96
        return qm_amplifier

    @staticmethod
    def _sift_sentiment_scores(sentiments):
        # want separate positive versus negative sentiment scores
        pos_sum = 0.0
        neg_sum = 0.0
        neu_count = 0
        for sentiment_score in sentiments:
            if sentiment_score > 0:
                pos_sum += (float(sentiment_score) + 1)  # compensates for neutral words that are counted as 1
            if sentiment_score < 0:
                neg_sum += (float(sentiment_score) - 1)  # when used with math.fabs(), compensates for neutrals
            if sentiment_score == 0:
                neu_count += 1
        return pos_sum, neg_sum, neu_count

    def score_valence(self, sentiments, text):
        if sentiments:
            sum_s = float(sum(sentiments))
            # compute and add emphasis from punctuation in text
            punct_emph_amplifier = self._punctuation_emphasis(text)
            if sum_s > 0:
                sum_s += punct_emph_amplifier
            elif sum_s < 0:
                sum_s -= punct_emph_amplifier

            compound = normalize(sum_s)
            # discriminate between positive, negative and neutral sentiment scores
            pos_sum, neg_sum, neu_count = self._sift_sentiment_scores(sentiments)

            if pos_sum > math.fabs(neg_sum):
                pos_sum += punct_emph_amplifier
            elif pos_sum < math.fabs(neg_sum):
                neg_sum -= punct_emph_amplifier

            total = pos_sum + math.fabs(neg_sum) + neu_count
            pos = math.fabs(pos_sum / total)
            neg = math.fabs(neg_sum / total)
            neu = math.fabs(neu_count / total)

        else:
            compound = 0.0
            pos = 0.0
            neg = 0.0
            neu = 0.0

        sentiment_dict = \
            {"neg": round(neg, 3),
             "neu": round(neu, 3),
             "pos": round(pos, 3),
             "compound": round(compound, 4)}

        return compound

# %%
##below is the code to associate each business with their associated
##reviews score from Yelp Data

# %%
import pandas as pd
import nltk
import numpy as np
from nltk.corpus import stopwords 
from tqdm import tqdm
from collections import *
import operator

yelp_comments = pd.read_csv('reviews.csv')

# %%
yelp_comments.head()
# Out:
#    Unnamed: 0             business_id  friend_count  ghost  \
# 0           0  bSQGCheX1BwvL67Az1OJlA            90  False
# 1           1  bSQGCheX1BwvL67Az1OJlA             0  False
# 2           2  bSQGCheX1BwvL67Az1OJlA            52  False
# 3           3  Z7JV11GXw_RsGr8Ik_Hsag             0  False
# 4           4  Z7JV11GXw_RsGr8Ik_Hsag             0  False
#
#                                              img_dsc  \
# 0                                                 []
# 1                                                 []
# 2  ["Photo of Sleep Country - Toronto, ON, Canada...
# 3                                                 []
# 4                                                 []
#
#                                              img_url     nr  photo_count  \
# 0                                                 []  False        231.0
# 1                                                 []  False          9.0
# 2  ['https://s3-media1.fl.yelpcdn.com/bphoto/E_gL...  False         27.0
# 3                                                 []  False          NaN
# 4                                                 []  False          NaN
#
#    rating  review_count review_date               review_id review_language  \
# 0     5.0            82    9/5/2018  NjYpdf2W7_2UU691w9Rlnw              en
# 1     1.0            43    3/6/2018  G2hammYtHvmlAd19sbRRug              en
# 2     1.0            31   7/30/2016  skBVzVCI4AZ0VCZKbSeFEA              en
# 3     5.0             3  12/16/2018  Bu6BZ8AQ2Rr3py6R_qKuWA              en
# 4     5.0             5    8/6/2014  deSmyPr4G1-sNlnGOTtx3w              en
#
#                                          review_text          ufc  \
# 0  I had a good experience at this store. I was g...  [10, 1, 10]
# 1  I reaaaaaally wish I had read all the stories ...    [0, 0, 0]
# 2  Everything was fine until the delivery. I wait...    [3, 1, 2]
# 3  Thought I had bed bugs, but it turned out to b...    [0, 0, 0]
# 4  When we called, Mr. Akram was willing to come ...    [1, 0, 0]
#
#                   user_id                      user_loc  vote_count
# 0  q41qqkChL9fRxF43cnkgbw                   Houston, TX        11.0
# 1  tNT5I9-QcljS-7w_doXCXQ               Toronto, Canada         0.0
# 2  9q1Do6TVM27RNHUQAQxPRg               Toronto, Canada         3.0
# 3  cr-4gAf1_seYWLoO59Lp4w  Old Toronto, Toronto, Canada         0.0
# 4  CQkTIyhNczRlRI4kIdAzSw               Toronto, Canada         1.0

# %%
##Create Dictionary to associate each business with their repsective score


if __name__ == '__main__':
    
    analyzer = SentimentIntensityAnalyzer()
    
##store_dict={BusinessID:Vader Sentiments score from Yelp Reviews Data}
    store_dict={}
    positive_dict={}
    negative_dict={}
    neutral_dict={}
        
    for i in range(yelp_comments.shape[0]):
        counter = 0;
        if (isinstance(yelp_comments.iloc[i][13], str)):
            x= yelp_comments.iloc[i][13].split(". ")
            for sentence in x:
                vs = analyzer.polarity_scores(sentence)
                counter+=vs;
            final_score= counter/ len(x)
            store_dict[yelp_comments.iloc[i][1]]= round(final_score,4)
            if final_score<0:
                negative_dict[yelp_comments.iloc[i][1]]= round(final_score,4)
            elif final_score>0:
                positive_dict[yelp_comments.iloc[i][1]]= round(final_score,4)
            elif final_score==0:
                neutral_dict[yelp_comments.iloc[i][1]]= round(final_score,4)

# %%
store_dict
# Out:
# {'bSQGCheX1BwvL67Az1OJlA': -0.0105,
#  'Z7JV11GXw_RsGr8Ik_Hsag': 0.1239,
#  'kI7ObOAe-Wvjdtnv-8Cu7w': 0.5577,
#  'Xo1LNzhnwE-ilqsM3ybs9Q': -0.0294,
#  '83V1E_ePwuLMW5EI40fIBQ': 0.0802,
#  'hvsiHkShRScStLyJ9rTNLg': 0.0381,
#  'cPDc_KWaG0zMmfvILWnnVA': 0.0484,
#  'oRRCe6RruoHE1nMfTlMREA': 0.3606,
#  '7ZfB-62Q8q-XpCdNFef1Iw': 0.1516,
#  'nWFP0KxQYX3_04nixuIR5g': 0.4525,
#  'UsDiW_yiyfRvqBd8Ct80Xw': -0.7837,
#  'IXhRytaICQEtNi-eO4wbsw': 0.1061,
#  'lVomzvlzgjsBa8Szcrt93A': 0.358,
#  'XDU_Bc6IOxm_2Nu2_U7rog': -0.0023,
#  'Sg8yJcPrDzCxkpBWWM9B4w': -0.0049,
#  'GxxHvymHBJrowNEZG6kNkQ': 0.3995,
#  'prK7ZzvlXNmJfY6PWUd-Ag': 0.0,
#  'qhtGHIO1Qgxjh4-8Ij8Tzw': -0.2829,
#  '44oCD8nZ00yBKXRGf5mNrQ': 0.4669,
#  'oWYzzx-hs4jVNHW0xLWUtA': 0.2382,
#  'bNCEH6ae9uPesqp-F-N9GQ': 0.4404,
#  'SIcv00YBda9mv0S0VLrtWQ': 0.4157,
#  'THi7Ry4tsNwQL16BodUSQA': 0.2868,
#  'emBRUqqNDMCJMUtnJrgJuw': 0.4411,
#  '5Rk1uBRv7aBN-uUi6B-CVA': 0.0607,
#  'FNlWIM2O4NnqxZPhotQsXA': -0.1664,
#  'C_MKyyEaJVUTldNujrnTZQ': 0.244,
#  '8_MRG-NLlgdK97jVtt0MYg': 0.4577,
#  'e0xVbkOUX1uazyyHGYnzPA': 0.044,
#  'D5oYTE-sbkV2wurOWOGzjQ': 0.4147,
#  'gISrxk4A5dfrjDivkC-L-Q': 0.5074,
#  'IHik69L1QjWkEN9qzIkDDQ': 0.1305,
#  'jR7AJiT2B6sCI1pCSvBw8g': -0.0823,
#  'nNd8urSlCVN_QN9IKKG5PQ': -0.1591,
#  '5C57zUQdzvNrCus8JBawmQ': 0.315,
#  'EUl6imNGBn4KYmlIbK35Rw': -0.7011,
#  'pIcE7Nwk_VJibEi630bt-g': 0.6867,
#  'kSSA0yX8E4OYPtvG_rGzPw': -0.2161,
#  'BPe1xWtGD0mY1tAxBOaLSQ': 0.3624,
#  'pG6yo-uDO-V334Uxb0kYzQ': 0.4199,
#  'FUqvrauxIP8bcI2aVeoXdg': -0.0407,
#  'y0QzKWNVoXCbZpk6uhEgGA': 0.2978,
#  'uumU_h3h0mTqwMub2AlWGg': 0.4633,
#  'ZVwLm-m8UulNLbbAHSjfjQ': 0.5985,
#  'RwmRKgMM-Y4ZODlggCD0Kg': 0.2076,
#  'LSh_-l4KuLAlP7IuJMynCA': 0.0,
#  'Dfv3IhlGS4nmZiFt8CU3xA': 0.1591,
#  'wcYar8rgLFA7Mu3wJUqEgQ': 0.2516,
#  'BgLp1LO_DdQvEQOERBV-dg': 0.4926,
#  'pY2kyXG_8aEvXu5TOnmIcg': 0.3879,
#  '8KYOCZG52i2l6zkF4rtuZg': 0.2497,
#  'CFppncp85zpyqFRcaVw1dQ': 0.6602,
#  'iAZbDOrujANUxBNCEebIsw': -0.1752,
#  'n3UhWKId2qeqq9jC04EK1Q': 0.2407,
#  '3M5BifnjLxhtJClUL-ILdA': -0.1353,
#  'Q-cNS-72xw4Kd-_O9cB7cw': 0.5866,
#  '82A4J-aOSxTUpuaSV2WVfg': -0.0184,
#  'b-doJn9r_ECLlgxezYv0CA': 0.0,
#  '7PeHmWoovUlH8pK6tJNn8A': 0.0144,
#  'vf48OqyfBypdGYwJN7PXrQ': 0.4161,
#  'Ay0g8Fnn-yZZkbarz4c5Fg': 0.4279,
#  'Mhqgto-7uOzquh1zMz1M9A': -0.1942,
#  'oiocguLkMNwH6gux2wxMfQ': 0.3258,
#  'PxH02Eu2Z4MUycBLU80D8g': 0.6046,
#  '3di3C5aFqi0SHheBYqgHLg': 0.5697,
#  'Mt3FH0HY2E-GHzLuKPxJug': 0.5117,
#  'pfL2h0ZBL8PgfcufpLMRew': 0.3174,
#  'TjY8caI9nMF8eULRI1kuRQ': 0.6511,
#  'xbMC-qLLtIoR4soEVTTL7g': 0.0621,
#  'laM_PIoHQ9LzCxXnl6C87w': 0.1663,
#  'u28SYjn6swe7A2DWdgZ7NQ': 0.4011,
#  'DN41zEsg2Nem0vK_j1gjTw': 0.3492,
#  'LYuY6kXhZzFtxR51eUiRvQ': 0.4944,
#  'w7kJ-mnx7gne5R09d8yxzQ': -0.1203,
#  'VTa35L-Z0GDqid9NYleuXA': -0.3038,
#  'XYyJ-hDPVrfJzLt4eeqO4Q': 0.5144,
#  'WuX9wbzEhK0lt9T-pVd8RA': -0.3392,
#  'yBInLNaXJHElJ7SbeRpyJA': 0.7841,
#  '3qROyHCn0LOJ1lNabW6FYA': -0.1816,
#  'LhWwwDJ2l79a1tHrpcdK6A': 0.0931,
#  '-sssVvXVRTgPN_ppFgeJcQ': 0.4216,
#  'oALEfNW0p5OxY_4-n_XzVg': -0.1366,
#  'T5G-WS6ER0TZ4aZou8Kbfw': 0.0308,
#  'Pmdhrz9hSjYbNGVoXC320w': 0.4235,
#  'qDpHsvRhgWWPZPXH_EVzlA': 0.0251,
#  'uTgyNTMWkgskaHIrMOsiFQ': 0.1698,
#  'QXqrx-OxKuBcr_iebwLoNQ': 0.3231,
#  'ye9fmMm1DyBTBjMMRVDgDQ': 0.4464,
#  'SbvK2WDetkBv2HFE0O5LqQ': 0.2468,
#  '2Ff3ixS3vA70xBcN7pVo9g': 0.4634,
#  'CRzxHi9gtFiIW-8TG-DJkg': 0.2327,
#  'JiecNolGPkAMAsgkK3E4MA': 0.2202,
#  'fAscHigioH6HC4tPIFYVyA': -0.0743,
#  '2zmsElyBgX5MT7dWoxsQlA': 0.1208,
#  'O2jkZ3aNd4XXZp1P9GpVgQ': 0.5811,
#  'B1zORkLMudZA65qel6Zd4A': -0.1179,
#  'G1TDV3WgNmW5QpWg7Grjxw': -0.1464,
#  '1gVyVdZk7G3QRCMF4aEOhg': 0.6741,
#  '0NRGv392ABzVbWwpq3CnBw': 0.7908,
#  'cQOSCy2ScdVxiNJplxOWAA': -0.0455,
#  'QR8dpEJX_TiMIP82ZsRBQQ': 0.5874,
#  'h3Da8vcJlMVwGvqLYC97_w': -0.9466,
#  'sHdHw5Ta1QC37vAdaGJvAQ': -0.2232,
#  'SWlJ6J-ao-NMhBhaXf4POQ': 0.4038,
#  '7rFykliIQJOPGlaZWnLibA': 0.3567,
#  'bACe6Z6jCN6KYqmfMKUfWw': 0.1836,
#  'Y3A4vmYUtBL43zg8RkveBw': 0.4183,
#  'pRRs9xT5j6H1m2WxEjOHYA': 0.5529,
#  'ZhZInBsTdQGr9YPjPn89QQ': 0.3113,
#  '0ThVVavKhsFct_apJ-vQ7w': 0.4701,
#  '4Nbxw5B5XarZld4uNZ-p5g': -0.2873,
#  'K0gZ9EQrzbVY_S8eY2GNsw': 0.229,
#  'WUlqkqBP9vxu5YBsUpq5_A': 0.247,
#  'WH7DESKCV6f1ix-QR_ETFQ': -0.3038,
#  'lnIAdTkMR-ShxhXzkfJK0A': 0.519,
#  'nyNHewITdpNZiTX3XtUcXQ': 0.4111,
#  'msmfbDZ-rYw6fyfdoS42iA': 0.4456,
#  'j-b0DJ00N4gkF9f0MamGxQ': 0.5949,
#  'ZOM-PkcGrSvd-Cg2npaOvw': 0.3798,
#  'MW1vK27V6fqOPbJcRnttsQ': 0.4371,
#  'Zt_1fsZsXXWVnqFBrMkqZw': 0.3961,
#  'aTu208MAv9lg8Ea4V63GbA': 0.4186,
#  '65ZGMedBm7TBpWv6fzH2_Q': 0.1149,
#  'DFFiZZyCjciD_j1wgM3N0w': 0.6562,
#  '_ZOv4_sq6B8rfSMA0IQN9Q': 0.3516,
#  'MvVK1T4_-PRw0bniyy9Log': 0.5409,
#  'BfZgUIMJgEu2Y4tLQKu46g': 0.4094,
#  '8oq_5_3RfPNzjcN304pOpA': 0.205,
#  '1cGgVvEbuBlW2GDvJ112vA': 0.396,
#  '25IJ2tocJfC1ufW-qnRjMw': 0.2217,
#  'EzVS1KGjsPOvGJZHuDr1oA': 0.5597,
#  'FWRtx_h3plgIq-9pucg_9w': 0.2907,
#  'AFF2vsQmRT4L22AvUsit-Q': -0.0944,
#  '4UuygjFYAE-qhCWWXycquA': 0.4877,
#  'sB-XjxJybYmPO1IPnRjc-Q': 0.4037,
#  'mpGRVU87qmvGohqo8hNnIg': -0.0444,
#  'bUBaYm6kGse-9XO-4caQYQ': 0.0951,
#  'MxiIRbKhCgT9Dz0hXg92vw': 0.1246,
#  'Sib5SNwugkrRvr4H-ERDCw': 0.1784,
#  '7C5HsQmANtKEw-cURa6bpA': 0.0635,
#  'qC6yjafmiJTitddIJAJpjQ': -0.1369,
#  'Lx6f77pZfCm3mnY74oB-yQ': -0.4755,
#  'Z3w_q-zJJlJeA47zxw8cEg': -0.1001,
#  '0TCn9BonClf7NUeoewCu9g': 0.4128,
#  'Tcxm96uXXxKQqkaEfqcc2Q': 0.0123,
#  'xqjzc8Bo_SyZdZ5gjfEwAQ': 0.1113,
#  'Dvwh_kb3dxe1WCbD6de8KQ': 0.8747,
#  'ajOZheHZu7rNjXmrwU5ftA': 0.2161,
#  'k1-W5lFhQpF36tfzU3UkPQ': 0.6703,
#  'CB8HrynUWR4Odnj-XTY-Ew': 0.459,
#  'cYOLwf89FWURahLWqPsoTw': 0.0265,
#  '4XwVW_LhDYhjeOdG1mMhDQ': 0.0202,
#  'C7MV_E1a3qmNbndwDgNLPA': 0.5171,
#  'S6k0qY25TxNywfCYLby4Hg': 0.5538,
#  'HdQrBS3jrtOrRqzRymgiig': 0.4306,
#  '_gyUi1KbhLvLJp7QFF_gbw': 0.3392,
#  'u8tDoGtdvFNgo0eNXVqoUg': -0.2125,
#  'BZltU3tkurGnqCNK7umBfw': 0.796,
#  '3PHqPzxlRbSFUN466ylJYQ': 0.2029,
#  'pf3ImlVTUPDapYqQ_VoOSg': -0.0486,
#  'uHgQgxfksSyqTzRRfRh0_w': 0.3193,
#  'kID7vRYvHWcWuHWpaWZgug': 0.1953,
#  'n3TxGaQ_PJmkQznqDdWYwg': 0.4337,
#  'VkES8QzWuy7uksPbbhTNgA': 0.0992,
#  'RTwBrHGcLUzOrmlWc2TNLg': 0.6733,
#  '8uOkQTLPXfG0lC59jLhcBg': 0.4308,
#  '8cSLyxVGzdGnYtm_mXUlaw': 0.7142,
#  'XpPursLpEPMEIUAASJUIpg': -0.1073,
#  '3pVhEwRS7eNwDgESPXZWKg': 0.4342,
#  'mxEXOkK-zji3VfDr1CLFAA': 0.0947,
#  'dKqA5KZIJ7aHq4GylpSmrQ': 0.3085,
#  'tHlJKmUECTlj2amcGG0TOQ': 0.1512,
#  'O4I0p0-Sl6FhPEDBxPcKtg': 0.2149,
#  'zJg4xavT9Jcd8EyRrgyRdw': 0.613,
#  '9f5ysbKpim-4-eB_4gzq0g': -0.1916,
#  'Ts4GQFagpeZ-wcdGUoMUKA': 0.2669,
#  'IJZrpASpveRG_BZAnP_z3w': 0.028,
#  'P2FjgtCQWYe1hXFslFCVdQ': 0.071,
#  'NX88XnZQOVbaSVj1exilLA': -0.0511,
#  'PaM8-tqEnxJMz995ImJ83w': 0.4187,
#  '-M9S1wlZTvv6T9EOo5X2Yw': 0.406,
#  'Ws-icpGHZrESFehQoAEYcw': 0.7665,
#  'oDBz4UnpaAVkBFGEAUaQPA': 0.2263,
#  'trkaJRx8nhdcfy8kxnALIQ': 0.5966,
#  'mGNbnCvQOwn8jGF_ITGkpQ': 0.324,
#  '9EMqhZW6CsyAUuJUMvRjPw': 0.847,
#  'MXlwfLOresMN0Ktq0qtrVA': 0.2304,
#  'OQhQlhiHcMAS0ixwDRFBNg': -0.1137,
#  'UNrAjQvmbszSL6SmV9FIyg': 0.1812,
#  'eUnQjeTDSuNlwrW94OdeEQ': -0.1575,
#  'ZdzM2tQGLr1A4McNaxvu1w': 0.1117,
#  'Ow0xR8GwgDreCcfPfFV8Tg': 0.2388,
#  'exjEzDg2ToZ66p6IY02ynA': 0.1134,
#  'BqTTdCMNJLy14nHLbTUSgQ': 0.3916,
#  'I2vROqzaM0uUqgVUZ_AARg': 0.4543,
#  'oE1EuKY2GmpfIiSGy3YmGw': 0.5281,
#  'eDqL9JiIxZz-A0xAbccKyA': 0.6209,
#  'CIsHnoLZHT24xwyT7FO09g': 0.4679,
#  'u_9Torx6PTineEJcD1wiyA': 0.5049,
#  'cukfuf1oI9tvslSq6lKA-g': -0.3407,
#  'StM_3f1nJw4tyK4Vx9W_pg': -0.0645,
#  'L_tieGcFMQVSmk7XiA093A': 0.3589,
#  'l-kV62e7u3nVQ-ofb-Zoyg': 0.1952,
#  'Tq2hB8j1-cpsMZNguXfpuw': 0.5631,
#  'uacD8ohETCv7v6-5kFNl8Q': 0.3076,
#  'LGCgkwygyz4IzNoaD5sgDA': -0.1239,
#  'vVSWB10p6knzgeVm2gtvkA': 0.1136,
#  'SlzdyggmZg_1xKKFfpHxAw': 0.5288,
#  'aWY2oMhlD_SkJrYm5GQzEQ': -0.1882,
#  'piZxRrpjsbUG-A_l5Y2PFg': 0.2715,
#  'sTM5Mgm7htjyVCcKV3-zTQ': 0.3827,
#  '0S8UyXMe_VBnNNNSuJ0RmA': 0.434,
#  '3UdhRjoh_ZiKRJi3bpbpQA': -0.2468,
#  'P5sdpe3FRxsDAwGOgUQQYA': 0.7615,
#  '4cIUCLqLuV2Y1ZlKfjjTPA': 0.307,
#  'ned6rO3oHsjznKj_q0g_aQ': -0.0069,
#  'nKuRxsEsldWAbU7_PAkaKQ': -0.5423,
#  'SiCdlziD8PjFO8HXDiV0NA': -0.0142,
#  'WJgnFrsHagdPMuAsAMW5Mw': -0.2508,
#  'QIUheP5W2cpvOA7ipSd9wA': -0.0061,
#  'G2-c6ZjbCtEmotaErAUtng': 0.0748,
#  '-ZppDJFo_hFkGTJXrWVY5A': 0.1132,
#  'n9sYGvhDXPO3qALuR_nYyw': 0.9708,
#  'PDQY2AHNmCNoFCv_NTM2ZQ': 0.0926,
#  'G7uzIHOTh4pE5VT-Z_14-w': 0.1049,
#  'QmZLB8eTeQ3e1BnDMan9xg': 0.1311,
#  'Wcj5XPJarxcTgb9dloMACQ': 0.1158,
#  '-WDTR5MkTxCzyo2r4nRqTA': 0.4251,
#  '_ZLyYJUy8bJJplTyVi1Oug': -0.186,
#  'Ee7fjlJdmLa4RJlzKunhrQ': 0.398,
#  'AYHp0ygY3kxqL4jrvqoGWQ': -0.0309,
#  'lL140WdMEtMYkM2Gn4hb_g': 0.2641,
#  'HTS0bw6so3lQExcGfrCC0w': 0.6276,
#  'HD10w7sMM9HkF4pM8BlJZQ': 0.8635,
#  'h6Hnu9nA-ORjXeJiuta9UQ': 0.3412,
#  'tlOdqhcAmozKEQ--3qtuWg': -0.3362,
#  'FP50uMIuMCODN_O3VVTlzw': 0.3098,
#  'OEWYxTVoEDuBlR4D8lybOg': -0.1664,
#  'F5EQ4DSznyIM1X0ht45oZQ': 0.7168,
#  'KB87OGISeBb5RE6tHO3vHQ': 0.3708,
#  '740JyMAEZy2luKUgu_KIAg': 0.1941,
#  'fWtro4avh88nckn-Mi7l1w': 0.2391,
#  'GIF-mBDilH8yo8rwF6j-pg': 0.2521,
#  '2Jkxqz7gwvpDuLDBS7966A': -0.243,
#  '1_5MnIFrC1I_ZShHr1wGZA': 0.2443,
#  'KacLABuXg3JvfssoveHKJA': -0.6358,
#  'cvKpmAvZE6Hf43d4plLvEw': 0.0206,
#  '-aLb0caPy8zXJm3EIPhnsg': 0.3235,
#  '1lkX72n61i4eJInmnkgVdw': -0.0485,
#  '-g4CC11SsaLYeQ5mjRxSfw': -0.1295,
#  'z0To8IgDPFzvMPP1Z8vG3w': 0.677,
#  '4B6DT8FgvI3i-93uzxH5fg': 0.2676,
#  'TYyMwKE4t2i3r6586o7NLg': -0.0717,
#  '1w0Tko5c-8HxsAdOUX81lg': 0.2876,
#  'O74EcHRmpxdsdzfm57NJ-w': -0.0979,
#  'eliSJZgoxjzEis_v6fmUXg': 0.3064,
#  '9EfhFpF4VByaEBbU61g2UQ': 0.2332,
#  '0_X7SPApe1126cHB6bNhlg': -0.0987,
#  'Iz3kiFhru8ndTf2rY-7_kA': 0.599,
#  'GMwL980d7cUEQl8VzJOebg': 0.0574,
#  'C16ogi6ASv-sQW3SGScmNQ': 0.6553,
#  'yJxPgF45B7ZgBVNhmSyngw': 0.4711,
#  'bg3fmqe2X8Uxlh5mHUjJCw': 0.1108,
#  'vcQ-rlyTFt2wqq9TrKc6Rg': 0.8074,
#  'SUKs1RfBMczpaHulOsmlmQ': -0.0903,
#  'Z4WSbG1WKTVOnbn7bDudfg': -0.1529,
#  'EwT6nbt4z6Z0f0zgfILjOw': 0.2263,
#  'RMamX0TwNJv3bq1oqJi-VA': -0.0119,
#  'Yj1jxPxtFPz8kcEkYnAcOw': 0.0124,
#  'EoMJdi4FxWE7guhsAr-kBw': -0.1709,
#  'mCsZn80l6eWxxiJ1uoK7rA': 0.0482,
#  'TnuL2q2mc7O_J73oVve7fw': 0.0132,
#  'PZ08ZO0-t2r1qA5WDd6wfA': 0.1544,
#  'Qgi_Q6PkF5D489t45vU_8g': 0.6932,
#  'wIUm2zTV0PtuAwloXm1WfA': 0.2685,
#  'k-QAr2nXxnYa-rrQYfoODQ': -0.2598,
#  'GFefOKzqRcUs_HzgpZbdAA': 0.0875,
#  'KX3trXmTFXP1kpwtRsi0Jw': -0.0853,
#  'hXAWdtY_e7svrGSZ-fb5WA': -0.3789,
#  'ujXFkSc9CCE9B1yB1ZSLmQ': -0.0372,
#  'e5SOabnBi0gKZ_PDFnjodA': 0.0955,
#  'djVzd-9vZWisUKYDnn1TWA': -0.3775,
#  'gMjQvMDihWj8I3h3tYNZFA': 0.2567,
#  'suDQ9Xn1BlN5zvFffCec4w': -0.1311,
#  'HgzIfRWS2TUmcUfOc3ZmhQ': 0.9141,
#  'w0i9nB6joZxpoTVeXzbv-g': 0.4899,
#  'rKNiIvWmzb9aqKgEDDztPw': -0.3006,
#  'ywgJ0rEaw0iUgRCMt0r3vA': 0.4588,
#  'O0cJmLYJjOKRxVhEhAlfLg': 0.1673,
#  '2vFENaiLsOZT1qymO0Jq-Q': 0.0233,
#  'T9ApAqMiuWFjrYr_ZHzX1w': 0.0427,
#  'dSt1ohSzTEbwosyfdUmwOA': 0.9714,
#  'm3U4Pey_Yr0jgJb8MHfy5g': 0.151,
#  'b2Lsrjj65NMa-MO50nEPkA': 0.1468,
#  'xbCLTxUYvm1ZMzBYtKEq4w': 0.4585,
#  '4vQqEqcgs2G6Yw7wNF6tvA': 0.3713,
#  'VezrSdSKsYX5jtiuMfYa-Q': 0.0321,
#  'Wz1OgzK_4fOAlJp5UCbPKA': 0.4154,
#  'QCq7ykXnyMPjb2VL7zzhQQ': 0.4008,
#  'CngPbUoJzsdpjGMdQFWP6Q': 0.6458,
#  'tEUvjMgAqwE0OE0BIIe6Fw': 0.0494,
#  'reWJsdKX1hzJwPCBj2Fcpg': 0.466,
#  '4SQvBWjDh_eUx_10M-eigA': -0.0552,
#  'DXPUHcezxV1YlciY6oqsOw': 0.4005,
#  'gHd7b3NTvD3IBbOEhPERwA': -0.0444,
#  '1DtyA7pnc66hTkv64lKlzw': 0.4341,
#  'd1jX8-dzwCJSkx9lVdB29Q': 0.1045,
#  'pNPHMJbOZXhP5V6bI2KaRQ': 0.3477,
#  'EwHgw3rDJiqU3XDJvcpR8w': 0.3874,
#  'iykCwxcMPzKQ2OEfYLK-BQ': 0.2411,
#  'PECZ9xfK5fjgsuc2Rwufjw': -0.16,
#  'i98bG3x6orc9TiIw7Xouew': 0.9716,
#  'MKUzLddRYHAjC-HlswIppQ': 0.7195,
#  'BSiYlhyHQj1MeA6cBd6bmA': 0.2059,
#  'QMB3hmb_Yv6Vk-HLiM2cdA': 0.2784,
#  'pv5uYkAEspbOeCQ6fMtCfw': 0.5759,
#  '2gh0_bmHNCkl2ZGLhC97nw': -0.5423,
#  'Sa-4-thVltHoYkWYE4ZTcQ': 0.4339,
#  'ed3DtCasPymHqJ_0EKzmKg': 0.1703,
#  'otI0jgKa39SZR-DG_rSyeg': 0.1803,
#  'H_YBTOS23PRhrjWtP7TeJw': 0.0363,
#  'aycqFnXoHz7STPWxttQHaQ': 0.3926,
#  '2L00cvfAAD6cZVUvYKDLNQ': 0.0184,
#  'xi109DyT11hpD93z4FAHug': 0.6088,
#  'aS9B-1bq6-zo-yJTuponxw': 0.5786,
#  'KGC9CjzGOfjrgZJtauY8rw': 0.3195,
#  'OWirYpHSvWeMuEuP2zYHIw': 0.0759,
#  'SULcDxEiJpN45nxPd6VwZg': 0.4215,
#  '2reVz4qVRTR8oRgl9lF4aA': -0.2185,
#  'E6ANxVcnIZ9B4Ub6Ph5srQ': 0.6283,
#  'w5fHHpK0BN7pu9bdmuw-6Q': -0.2196,
#  'l_k2Mj7MxtbaIyp9tFe_lQ': 0.2579,
#  '6mI2kt70hiOb0UaNYXfS8w': 0.4952,
#  '-sA6d0VfeoctFfOvtO3fTg': 0.6757,
#  'yf4Bs3wqOWzwUw5HHmR3hw': 0.3304,
#  'w5jwfPRaQQuS58IxbFmsug': -0.0443,
#  'YxFwTAqZkafofE8_sewpJA': 0.3147,
#  'Edvhkok6G-f2nANwM6RkEw': 0.112,
#  '-OncGMvvHP-t1rjZ2IB0Ww': 0.0242,
#  '5gpuoGwBo_R69ImjPtpFBQ': 0.2069,
#  'Dpl8d6eXq-YnF5zEV1cwMw': -0.2732,
#  'LYWBA-dercUFBSR4WY65WQ': 0.1235,
#  'UpKfsn475Wnu4IWrHeuXkA': -0.0058,
#  'L_ID6NcJ1OcbBAjDWJElrg': -0.1916,
#  'XofTCNaFibB7NczNYBcqng': -0.0865,
#  'fV5rKrCwM30AUwj0JbNA-Q': 0.0569,
#  'WKOUTdVJS58E178JjhwidQ': 0.5776,
#  'fEHYeuPJ1CAlq02KNI88HA': -0.1226,
#  'YwTPgjSqfJ_ZQda_q3PE6g': 0.1317,
#  'jzRpawkcwmTmY9udyoyz2g': 0.1229,
#  'TaTjCuAu6digyuZNBo0fag': 0.3191,
#  'RIhQV7wRc-kBKPgsHBw6uQ': 0.0,
#  'J5E_fbNiyzltuHRvOKy8eg': 0.0626,
#  'ZbqOJzVWEtmuC4tkNygAxQ': -0.1475,
#  '-F6uKOdNYRV3ejbn7MiVNA': 0.1433,
#  'fH-8g35DnaPcCo0Fj-cKdw': 0.4681,
#  'GjgcKe6oCNtlsSNZIVTwog': -0.1367,
#  'RP1kWWOmyw6lydwtklbb2A': -0.0168,
#  'VrftSduLIducNfEzITOL5A': 0.1035,
#  '4Mp7Xgwfin2nWSuvHMeX0g': 0.3114,
#  'uEDTiYtWzFtJdJqRcPq8Lw': 0.635,
#  'wDufqbWIn9bBtHEv8HJETQ': 0.0121,
#  'LaaNEL9v5raChyag2vplNQ': 0.8118,
#  'nlai1j5FXlDZSw1RwvLIvw': 0.4391,
#  'LXpHtaR1mSgoopDd5dKlEA': 0.2556,
#  'ILpYdWLHFXC3dvW9cXPzcg': 0.689,
#  '-iSw0mnB-WWcEj6gYv4uPA': -0.1031,
#  'KzAxl5OMo3bOBUFsUULXUg': 0.0693,
#  'DcwkTT5aHdzjbDXt_E0whA': 0.489,
#  '9eu2lQMROTKdrPyGkwZLYw': 0.2677,
#  'vAiOsiJcyNiuFz0WDM8kiQ': 0.1058,
#  'bE7zwbaBHFb_EKWL5qOhHQ': 0.3268,
#  'Aml6g-8JAXVvjGRRMR6mHw': 0.32,
#  'aSBkGUD1x20jKi24haYVOQ': -0.0099,
#  'gPyuzzoNnfNfb90qMygp5Q': 0.6725,
#  'K1op8KS_gneKtgha1yLBzw': -0.0724,
#  'PFAvETr4Vf6UY548TWvhFA': -0.1898,
#  'drVrGXXSO5XC86SvaaEAlg': 0.6127,
#  'RT2ehQp-XqF6SHShqOCFkQ': -0.2206,
#  'cgOzP2kwfYeGhAReN8Ppuw': 0.3232,
#  'HmaQqHg5zasWieUD668OGA': 0.0028,
#  'KVjgSja0bGq3ud6YvaA6LQ': -0.4647,
#  'DP3R0B9Wds7UnUjtqApVbg': 0.4,
#  'SSmLW98jD6nKXo-SqR-Siw': 0.1326,
#  'G2ES3OhOycGuqj0wW14zXw': 0.1277,
#  'F-bdXFkJwwENiNpMTG2ntQ': 0.064,
#  'D5AAWYEhzMoi7OolrTbtmg': 0.9086,
#  'tisY41pPmexwHYTI0oQUcw': -0.2976,
#  'eYrjjYCxD00BBRUZ9p19Cw': 0.3697,
#  'Xmy2Hl1qpRLRQ-c7kg47yQ': -0.2329,
#  't8_UkZVkyv9r1arZ_ZfIJQ': 0.2857,
#  'HYIvIDsziK683_vudT33SQ': 0.5525,
#  '5dy8OiWJty9AuxBcBzeBZQ': 0.2427,
#  'sJP0GYO2pi7rwNFFcH7iBQ': 0.417,
#  '5OHW43gqdoWOGWDmUmps6A': -0.0891,
#  'U5oaLJwEb-NY7Muw0jot1g': 0.3533,
#  'CcQhwwhykjdlfaSuCmCrHA': 0.1237,
#  'DhgSsgKGpTA55F3qmhOoHA': 0.1742,
#  'mRnQ4g5EZfmEV1DwWp-Xrw': -0.057,
#  'd6Glyo7Nq5u0WOe2r_tJdw': 0.7745,
#  'OxMDmZDVYueJnhwRlfnyAQ': -0.0733,
#  'Z8_tlNAkosEzoCjTWatj7g': -0.2546,
#  'tz2GrXmqIFrLinyPWmzhUw': -0.0413,
#  '4PmsvMx8DdEwCqnIcPkXcQ': 0.6787,
#  'VXgMXIFa90rwehlRYQdf5A': 0.5815,
#  'h7QJlHamZJWxOsZ90itkQg': 0.5671,
#  'gJzmRmsCQ1149QSc0EhnFA': 0.2073,
#  'WjA-Ad5m6HMxaXRnzIN1zQ': 0.638,
#  '3tIl_N6pTr0UwLLg-pK5XA': 0.0585,
#  'sZkfaqq75sHnTvvskHbewA': 0.3795,
#  'HOZViPqF0XRqmkinHO86YQ': 0.6058,
#  '28dfWn2WpHJGp9p2W-maNQ': 0.4869,
#  'lWR0QmqjVXpCFPWRUSGFtg': 0.0581,
#  'L2LyLnarD7HX_PmASmtyjg': 0.5074,
#  'JIbFCwltn18bPDX6wp1vLQ': 0.3166,
#  'CEhjI_dQbFTZybaCfjzIvQ': 0.3477,
#  'ep7OEZ6puky2zp8hGbPa8w': 0.9626,
#  'MKiHVqUJg1YzLmUyveYXzA': -0.2249,
#  'KLy5DYNrxGywsXzgYK5lFQ': -0.2353,
#  'sJBxx8g53rPF9ISZF9BSAQ': 0.4797,
#  'Cy5VGp4Qhq6AI3Y9ukR2sA': -0.2865,
#  'qn7NS7xskVDb7oRrr4HpyQ': 0.6618,
#  'c9lKqE0zfbSF5UixUBJ9JA': -0.1736,
#  '2g_rDHzMb3_X2ay4B9rgtg': 0.129,
#  'lLHYZGvT4ZJfo_dKmpw5rw': 0.6488,
#  '3jNJMmPNWl6SQD_98fz-bQ': -0.9655,
#  's6U2JqtfX9EOHeOKlHY_Jg': -0.4767,
#  'GkwWHezarl4iUTRHw6bMfg': -0.3591,
#  'ZlWJAEg8Ilb8h0pcdyfUuA': -0.237,
#  'ZmQtrF27AC2YRsNVVku_Hg': -0.2066,
#  'IDHq2LXh0Nc5hv2NxRm3ZA': 0.1713,
#  'rqeaoQGP7UIo3ov7DRiqrg': 0.7943,
#  'GFbVxGcRE1vKLIf_6JZamg': 0.6948,
#  '5BKuIl0_wlzfFTXtcZzjgQ': 0.926,
#  'JDtGO5IeZINteE9g-Eqfdw': -0.0191,
#  'yHruSEL9nUze-dKupeNlJg': 0.9428,
#  'iSFgOSA5PqVKaRAJOJtX5Q': 0.4113,
#  'qsk1dBYqagtFaf72Xyni3A': 0.8353,
#  'F0AEXHjjMhJZtsA9O0iP1w': -0.32,
#  'oLS0qczitIoiYSpfKOZ3jQ': 0.4046,
#  'zthOa5crvIWCSX3XgT6cWQ': 0.4674,
#  'J-HgM82YM5yPrEXz5VpfWg': 0.4632,
#  'OLtNkVo4yNlgGNvO_r092Q': 0.3815,
#  'KWo7yznFXa-Q2l1aOXAwAA': 0.0315,
#  'xJGcBlVzymLv-uCMYbzHiA': 0.6817,
#  'zRxKrysFBrKH76yhyVdrRA': 0.5139,
#  's6q9az8gOtXP11QTKQ235A': -0.1486,
#  'Zcu642UYN8h9v7-Hq8kQMA': 0.275,
#  'JotRkYFXqP3iQxVmRN7W9Q': 0.9037,
#  'AZB4eddtfB90vyoB1o5N2g': -0.0895,
#  'NMMu2D_MBnfF5jpd--vGWA': -0.0317,
#  'Hnv34v3mDk3BtyUTW41tfw': -0.0424,
#  'apPQPFdy-cX7Poxi5R67dg': -0.3088,
#  '1mpJGozPVzLfVKNLrI5XVQ': 0.5217,
#  'owwc9Aq6NmK5KcmYj_4PAw': -0.0755,
#  '-YkA0gzgF28brr8_MAyzwg': -0.3688,
#  'DqUa0BFB1FB-qWm5XlwLhw': 0.5848,
#  '98R0IKLN75Oe87eMmiOa0A': 0.4814,
#  '5U9yBuUarppN_6jBwil51w': -0.2161,
#  'LJ7eVSfrfc_uZMWGr-d3xw': 0.555,
#  'r1RcdE3SAPBAItt1TVyjiA': -0.127,
#  '8QffAUCNxnrCtvbdQavfzw': 0.119,
#  'N-5LiIEdzxeJKd8EquiHaQ': -0.1473,
#  'ikgNy-Woa0H6iJW9bY4SUw': 0.4106,
#  'i6gKYG_YFuF5o90jPuWYvw': 0.4373,
#  'Bl8d3MRR1DsBRf1qFPgn0w': 0.5188,
#  '4ob57gqtxNaQfFuRdNp4mA': 0.1411,
#  'o5lXrR2YpdggtIFXKJEqxg': 0.246,
#  'odhwxNT5Y1qWB8v_rdmS6Q': 0.017,
#  'Fw6diOlq19JLCXdCMLY6gA': 0.3023,
#  '5kZCUUGOFxN-eAxFShfmXw': -0.3375,
#  'opvd8U6pD7UBMi05zvFOTQ': 0.4446,
#  'W0LzFmKUqyLeVuIWxHqMpQ': -0.6438,
#  'C_g3n0TGN9IVtwED4WiavA': 0.3698,
#  '0iOhYM-L1Kv4xioL6sq93A': 0.172,
#  'mE3JeKNsE7-scO7eW-omMg': 0.2711,
#  '3XVAfJQdX327pqNZg5KV5g': -0.0057,
#  'WbYAiWtGd2SfQaTcZ3pOaA': 0.4019,
#  'eE_611gM-wKg_2sMlTbZWQ': -0.0266,
#  'G-46GViMjTCtMMjaKZwCew': -0.6104,
#  'uhwRh2VtzXxwXoqL2dHqYw': 0.7388,
#  '4mfrFsmtEunuwe31kjVnOA': 0.4761,
#  'HWSM1RYbbxUaq6L2EOk98A': 0.3689,
#  '2sslQMFDlzk2yMcRGwSjdg': -0.0017,
#  '1X8ZOlo_eJu8IJS1Jx7k6A': -0.4699,
#  'oR4Q-2N_PYYUo9CSKXHoKA': 0.4173,
#  '6FLrYVqKnlC_XXDAG02ZYA': -0.2456,
#  '8p_kO92WzMgWtdqrVDxNDQ': 0.1819,
#  'qJA-fSlnamDWHtQxvJITfA': 0.7335,
#  'Fiq23fXJAcFsobkQaRqIkQ': 0.5246,
#  'lmDmacUl81tfUUxPJZwz9A': 0.2601,
#  'jb0UPg8DdWMnlA-VpJy1Og': -0.0939,
#  'XXBA1CbiH63LlrfUExWuiw': 0.0486,
#  'BC-nYv2Bhx6PikHV2JvWFw': 0.5178,
#  '9dcm28t5uChVobYdXddaiQ': -0.0929,
#  'AdFNz01yRFoZFvpZnV0CAQ': 0.2326,
#  'U6KCCwPhpXRIINtQT-2voQ': 0.0525,
#  'af1g5X4GLPUQqh_FC_TMow': -0.2977,
#  'sRdtwkUUfLqwmRGoMtguvQ': 0.6359,
#  'PUDtJu2bFTvIl1_WhyUIXQ': 0.7573,
#  'I5OvPnwSa1DDcB0cQwOulw': 0.0858,
#  'ouWCBFTtquhYWL-bnVtJ2g': -0.4195,
#  'Nm2VcfjOhShf5jStx5jt0g': 0.4603,
#  'V0mYyiVSPw2nU4ILMb-vhQ': 0.4452,
#  'fu56qdswcdww4CiX6UrRbw': 0.4443,
#  'ib-v67Thw1lQHGpzuZpb5Q': 0.201,
#  'n0xipiBLtvEu4Zd3a6KM6Q': 0.2488,
#  'JiYlmAqfqfiGK3JycqhOqw': -0.0131,
#  'l3an5w-q6UibcAwZ1PZnUw': 0.57,
#  'g66wj1KADcE9AetNMo1hSA': 0.6014,
#  'MwHb2yhgT8mBTT0ZXRw66Q': 0.7501,
#  'NRNIRY1uhvNZRhryXj2OLw': 0.0451,
#  '0lxDAsJD5IO0QjvPmQZHNA': 0.2006,
#  'fmrCTT5Ced_pvSuj32-TMA': 0.1806,
#  'sS8uO7UuWcW_17AMga4yKg': 0.2904,
#  'c-bZ55Nohj3MF3MlRLDy_Q': -0.2868,
#  'CDSNzkBDwWuDF5eRiJBrcA': -0.0363,
#  'de_nC08Q4yT2t4Y9C-phOA': 0.6218,
#  'yFMO4aoJ2xWW3AmSsBixtw': -0.2118,
#  'afey9aqBslkJUSuj6yot6A': 0.0112,
#  'Q7RXkILvPGl1pHSr5rJeSg': 0.4145,
#  'A0rmZ17EeglM5RtEWtfsDQ': 0.6265,
#  'uUZ2U2b3hqMM0_r9cEEchw': 0.2368,
#  'bCc7Fi46nrgZHhx9f5gIGg': 0.4327,
#  'QYZILd5h3E18X63E2rpCoA': -0.0207,
#  'JGggVNOTijX2kNrcbgqMmA': 0.4189,
#  'OAfDrdhLBLp1QNNCB3vRNA': -0.3912,
#  'SucJwTrxbA0ko8V0HddGzg': 0.3852,
#  'JS4Q7NYyvSrJ7Ki18Rr9jA': 0.609,
#  'cdA3MPcoVPYLrZzhR0_rmQ': 0.645,
#  '_LBkYG5mzMP9uEv87N2kkQ': 0.4426,
#  'WmJ1tNK8ex1BLOHMSx6PRg': -0.1069,
#  'DWJM8TpJyXXuwHu5-jGIow': 0.6672,
#  'pPjQJ2d6lmzQlI6BPZS1Xg': 0.4922,
#  'uT8ANzpmja5wgUP7lsAyAw': -0.2739,
#  'JNOHTwpu7JBgRZuunPQnOg': 0.3537,
#  'Ghp3_XpBwZqIUtIw6PZHJg': 0.4719,
#  'gIVjdDWRnS1yDVpPF3oUeg': 0.7352,
#  'ZGj9ABAV3GTZJz1esLsl6g': 0.1683,
#  'd0aJ8ZvfuSDcuDeYB1kCbQ': -0.1692,
#  'tJqPUAk3xU6IkFgagpD92A': 0.4079,
#  'bEnGTtU1eZ-gXAFpJXg-LA': 0.3488,
#  'vcuR8_MjplAl1He0hwHxTA': 0.1468,
#  'j28T6ZuP1mLHe3m36COOpQ': 0.2914,
#  '9jfx8EkHr-GwtBLc2_GwUQ': -0.2747,
#  'KbxzTAHeQyQzdep8z84esg': -0.2627,
#  'RgE3DT3S5zvArMJ9RhLNNA': 0.422,
#  'sba0M-OujM4j6Bx1oXrUzA': 0.0729,
#  'p0lRbYRpwPamH-vARek4YQ': 0.3919,
#  'R1wv7_R7i8aCD1OluvoXzQ': 0.0254,
#  'qxJrEuJz7CBeIYc3DnxoCw': 0.4677,
#  'PT-gSBLG28jU452TEEP0mA': -0.1303,
#  'kGEvZpKr9cCUaBRLhnevbQ': -0.1604,
#  'YOOyzyZI1uO9FCzXwby9qQ': 0.2,
#  'iw3biBcHIKYUHmj42CXGTw': -0.0326,
#  'Qi6eSF1O9WFdt9j6vPDKbw': 0.3026,
#  'sYQ5wGRg4gX2iWv6swG6Ng': 0.3016,
#  'Nmee7mqtplm1_djlxCNMWg': 0.1824,
#  'PbpQztIQ19BnY3Iw9lx9Zg': 0.6568,
#  'tCjlXROlbcaGiBRfU2jaiw': 0.2541,
#  'rZE9tA8RHtZbWV0NtzfPvA': 0.3659,
#  'XdbALxZ0obqkAfqwR3m8zg': 0.1477,
#  'dMipe28uBrRnqk8vhcoNgA': 0.1197,
#  'gwpPc1yHKaPsgfC3q5ce3g': 0.4365,
#  '6Ei61h-GUZAGrinbR1oqyA': 0.2527,
#  'e1OmjVd2ZgxzpjEiYTXyvQ': 0.3419,
#  'sog4i4LuTjlHUOzJSA81Nw': 0.0596,
#  '7QJAHvZG53rQx5L5uZlZAA': 0.0004,
#  'mZJUWoctPqgqTDw41tHqcA': 0.245,
#  '0KALAFvP0Jt6uSjkTlPXTQ': -0.0273,
#  'juNKWhkMynLaIHK4Yipxjw': -0.002,
#  '5FVTSx9CIzvA3i3AOVaj8g': 0.6621,
#  'QLJgZcBmWO8p-fMlnL8IOw': -0.0528,
#  'MlPKga4kdOSo5hZHLb--IQ': 0.2768,
#  '1xyXgMTYkVMV4KJhFRyV6A': -0.1998,
#  'OT9QKUmpD4-D44z-ZxG7MQ': -0.0492,
#  'N3CDEpX-3T5_ULMB6otPWA': 0.0042,
#  'lFSi4TGl_b41rYi1PAUZEw': -0.0065,
#  'lPYEtjJVlmm57MH3wUKzzA': 0.2927,
#  'jgydOn4SawS_9kzu1BJwgA': -0.1051,
#  'SkrSaQaXp8agHDBd7qU8zQ': 0.1232,
#  'cxFZ9pFvWvP2DWjw0-G5iQ': 0.969,
#  'PtCoeZkqZyejRUEpmXyppQ': -0.0671,
#  'nYKBZdzoA-kjqiK08IPSiA': 0.4148,
#  'OP-gjzFnGGIDSm5HDuXeZg': 0.2775,
#  '0JCJrv9itHlSo_IgYYI1KQ': -0.1827,
#  'TRG1rwkydMzRIlGbhHEwzA': 0.0159,
#  'lRXnM2xB7soyf39M-mIuYg': 0.1696,
#  'aGyeKUgWJT8NxuqLZrkUlg': 0.631,
#  'NDuUMJfrWk52RA-H-OtrpA': 0.2059,
#  'E91Yw0c91fKuIPbxABlVVw': 0.1948,
#  's6uFv3nQJwVxKT2vURFXVw': 0.6895,
#  'WvMkxBdYLTh8ikog84ghCA': 0.0311,
#  'elkRDhc518NMNiCd7ijW2w': 0.5499,
#  'n6Hfkk1tbzX6r34PsgLQLw': 0.1237,
#  'v63iFqSQcYbZ-rK6PHLT1Q': 0.2326,
#  'NPOBa116KVwqOZJvM-2zkQ': 0.0854,
#  'eWVjVaetTPb6qf-8dh9MHg': 0.3948,
#  'kXoJBWuaMZeVXDqPtHxaMQ': 0.0209,
#  'MxzDRVIeN5JdjdcmTv4Q3Q': 0.6687,
#  'EzN8_ATOdYD-fRtcGNSKyw': 0.466,
#  'aWlvKKSAE6ZFPK3ij6ubqg': -0.1249,
#  'emBmsSxiZGGaR2OFHvR9nA': -0.0487,
#  '7zfNFLf-SwjbAqhGqdx8Gg': 0.574,
#  'ydiJa50tPFKAO_lUU1Oy-w': -0.1647,
#  'k680CgmIEzesqGAAzXa3Dw': 0.041,
#  'loTu3Oa6amWsG7GfAeqbhw': -0.0294,
#  'RJx_V39W3KGO1ORr99NCBw': 0.0771,
#  'DKX7wdJXjwPqF2GeL17MGw': -0.3416,
#  'L-Vab1R9AWNBoE8jf6DCFA': -0.2211,
#  'YFamMJYgBmsFKj6x6xR_jg': 0.1283,
#  '-0NrB58jqKqJfuUCDupcsw': 0.1954,
#  'C_uTqA8IctcKHBL9JLEbLg': 0.2958,
#  'NHjM5lbI5LR8IDC7An2QFA': 0.4096,
#  '8idRgzKzCZ2l2_d7nUSQDQ': 0.2823,
#  'VEMX1R4xtF5AXwKlNMyDVg': 0.221,
#  'IOnYHKR_zh-cJqgIcCqsgg': 0.4856,
#  'yYuqSui8N0xesgiviE4evg': 0.4351,
#  'yRcxrCvF9uhHsbS8yEl3UA': 0.4205,
#  'aoTRvdPtQmyXHNM0fm2aUg': 0.14,
#  'tbag8KVu1vqFXkv6bsY07w': -0.5399,
#  'B09Dx1tUPPlUB9PD7FIP8g': -0.0272,
#  'TKQsft3JbRf3qRkU1eggrA': 0.3454,
#  'ss5PAmrm-tZE6zmDGF8zxw': 0.3566,
#  '-2SyD4TRARa8K2qWZ_gRBA': -0.0987,
#  'aKYuuU8Dssmngg3Bs_MCSQ': 0.1334,
#  'g29Wq8-qWAQok49AQO2WqQ': 0.0621,
#  '50-xiTYmE6NERi-yJ6NvHw': 0.0858,
#  '2TP8uQkMDo7Av5ATNJtI9Q': -0.0695,
#  'yKKI51fV43lGO2r3Dq0DMg': 0.6013,
#  'cIHLq8s39DC1BZBaowHbew': 0.0495,
#  'GDbjL5NW_2m8X61IZekrrw': 0.7725,
#  '7_AjzHBw5CMSCwfaKckd7A': 0.2122,
#  'GBXRbNshYs4QKxAeyXxT4A': 0.1662,
#  'OKK5OAWQaJ0Rz56pT5TcjA': 0.0304,
#  'dOHyn5WK2XNzJOJ0UwzLQQ': 0.9917,
#  '3vykxItKNuoeQjoYnATXpQ': -0.1046,
#  'JkHf22VHOZViw_Sdqp99Dw': 0.3166,
#  '-oml8rszBhp-x10YgVfJ8Q': 0.4401,
#  'sSkuryNASrDjIPcGZNyvWg': -0.137,
#  'Uq4S_qtPsC4c46FP5G3e1Q': 0.2252,
#  'S_ZNfL3adRAGYJ65C0sG5A': 0.0379,
#  'asp1mhto_8_Ps1C4ApK8iQ': 0.0,
#  'P_hxMztt6p0Z3c7wXoV2ig': 0.3124,
#  'B-ImbhdbVX0O_ulCZE8sQg': 0.2194,
#  '41o3MEJHzyBp3wADivMktQ': 0.2897,
#  '1W5VSOsR6p4YFN8NHeNznA': 0.2583,
#  'JXyta9p0inlx8Jb1lx94Pg': 0.1309,
#  'EsZPNABHmBqnUYLqO2dgxQ': -0.157,
#  'KzDJd8_d2Xf4GeVbWW2Rfw': 0.0621,
#  'nBo99rJ9dG6-hiKdo7E7gw': -0.4943,
#  'r_D-8FMLqFyRRy3ttWPWoQ': 0.0171,
#  'P9BRQ_q5BEyiiJw_dFvRSA': -0.0608,
#  '_-YlNH6UByMXfstQcHBYiw': -0.0348,
#  '6nGnVP7M4qQRiclXxeqXSQ': 0.2595,
#  'cWoBICebWSDxjYgsfrZ1dw': 0.1806,
#  'l-Iflh2Bgy1j1n_fjvT_OA': -0.1294,
#  'Gh5zgKz5I5aE0qbpP1T9QA': 0.1507,
#  'laf1pFq5K6KJCRC8X3VHOw': 0.3043,
#  'RzKR1EMiXF7ImgX0Lj_QGg': 0.7219,
#  '1iITBXm3BeKX5RtMLQAQnA': -0.2139,
#  'fe6YW5wLAeWQBATPf494DQ': 0.4248,
#  'GatyPPoMjF-kKPuBWUC07Q': 0.7879,
#  'BDfdu2caft45CMpm77IJmg': -0.1305,
#  'lFAK2yx9ud-M1XZh5DxssQ': 0.2888,
#  '6PvEIbj8JZYqTenNVnsGbg': -0.1461,
#  'eNGlnsBaWfRKkT-Wkn7omA': 0.2997,
#  'TMQzMWEFqCsVUYGTmdJJnw': 0.4046,
#  '7xHhVn27WxjdPNsfLYQz5w': 0.0227,
#  'ZqgTWUHFgX8k4nYKvi1Rqg': 0.1976,
#  'DfMHKTtAkahaWYyqykw9AQ': 0.0913,
#  'Zx-rz7D4DOT8Kmx97LFAjw': 0.6776,
#  'q7TzIlTXaaBJa0mHXW1gcQ': 0.2716,
#  '5GMdfctv9-UW5E08TGPUfw': 0.4134,
#  'K5NLWFM5RP5HIM0jbZC2xA': -0.2382,
#  'HczMx_z0HS_PnpdTHc3qzQ': 0.5827,
#  'Hz79RV53noQOyKqLxyhm2w': -0.3192,
#  'lLujm0yuar140PoNMDqStA': 0.0,
#  'zQRgTsipvU36PrEuC2pjaw': -0.0412,
#  'Xrdi4rrdWzVHVSNA96gTsQ': -0.0032,
#  'SLltnB_SKQKQvQzK_FEpwg': -0.0734,
#  'XUEZF1Nh2DYmtOEHbhYFEw': 0.2683,
#  '2i5qXM8Oz3j7D5hJ_uKeEg': 0.4454,
#  'JtllPvlJivU_8DTlH9s2vg': 0.1208,
#  'DprO2_-TACRiPiimbtXvVA': 0.8662,
#  'T6yj2qsoUbHTs6r_z6JAvg': 0.2847,
#  'FC1davfOlKxJmfuqto8zOg': 0.4559,
#  '8tbbGdbi_J0Oo2_KqZ3ahA': 0.3919,
#  '5SXhoj7rYXT3npwka2H5rg': 0.1169,
#  'bSLIrhdxrxuz3p_nz1iLpg': 0.0399,
#  'P0_sjOh0kQOwJJc-hsAMoA': 0.358,
#  'oJynEBZyqKcfJjDgfMgDTA': 0.6368,
#  'Ir4zL3MF7LX7b46qXn5WWQ': 0.3296,
#  '3lZnIpmc0pqtej3eCIOP0Q': 0.3091,
#  '6kAmioMkfjIR_5jztFCy2Q': -0.3421,
#  '6HR_XfN8RtOHbASwDGijuw': 0.1647,
#  'wNIo8Ocg1_w2zvq3411DqA': 0.3299,
#  'ZCdXbef51G3yyjVEXB7AYw': -0.0073,
#  'lnZhnZzBiG5rD9brVv5uXA': 0.7261,
#  'nAC8ivyqS93rJ0EkNvmWdw': -0.1204,
#  'bgphgt12AOMoY1_kBpVnKQ': 0.3752,
#  'NtmoaTIa5pLit1vDsW7bwg': 0.4056,
#  'VHamhfpM6WMxRE9cvRpnNw': 0.618,
#  '6l6DSY2BI9CPdDVb-hJKIA': -0.0632,
#  'tsavEEwk7kvYMl4l4enYAA': -0.2462,
#  'TCwV9189hvp_z0Xa-8HLtQ': 0.2192,
#  'jWfmC3iXaPLBmrAFfK2QeA': 0.4969,
#  'KbtUNrTfQqGlCFVnpk2JAg': 0.3524,
#  'pQI6zMl8L3I_i4JbphcnCw': -0.0558,
#  'm6pR8tXz7Vu7PcjD5EQXyg': -0.0819,
#  'zbT-UwvE9l5YxhlcN-2nRg': 0.247,
#  'TM9Eani6kQmRV5RZaU7Tew': 0.8529,
#  '9LE2yGl23qxitNc9mkpbjA': -0.1608,
#  's7Yaix-_9qfw-9UOGA1jJA': -0.0104,
#  'nKzQ18NXFFGExZwK_197pg': -0.5015,
#  'wzqB5PjfIxKUuENzzr01tA': 0.1946,
#  'HVXgsW9QIYAzsiaHBxsBDw': -0.1542,
#  'UO3bC8j0KmS35VbNC_00lQ': -0.3561,
#  'kgO6-UeYVJMpPHIBwXOnvg': 0.3011,
#  'JNH_NSfeetcVFpFBkeXEQA': 0.6669,
#  'NhJcC0PjkIDNYc4chtaCEQ': 0.638,
#  '5s7P8qWKPdi6WzFcdmOJHQ': 0.0424,
#  'qHHZgz3aoaiFCsgCkvTz8A': 0.3046,
#  'xvSuNUPM-NwXkmEzpzTVyA': -0.2222,
#  'moEU_B92vkkQmYKP0ahzKg': 0.5321,
#  '9vXft6qs5naiotBHBsQLfw': 0.552,
#  'uQvCvJ5wMZh0_-lisKhe1A': 0.027,
#  'RL6cDHhdiNHXQSQBOnGWLg': 0.4451,
#  'WwrKHFXpBqLQAkhmU01Xvw': 0.3622,
#  'a_bNJgQB8iQgF8_2t1D8Hw': -0.1211,
#  'ofG4TlKzwwzM-uCmjFRFYw': 0.417,
#  'NByukG_L5phed8QMOVxfgA': -0.3206,
#  '7ndISjR1w4cbJAOf0H35Iw': 0.4498,
#  'K-M22sGSieqPxxzJF_a7WA': 0.4578,
#  'mQSxupoy0S9CrbjXvezMng': 0.1058,
#  'VTVxtisauhij68JKsP7LbQ': -0.7469,
#  '4QD1ulP2QeBqG2LvnRGanA': 0.8217,
#  'tHejpimubCNPFhGqTsjyXQ': 0.5465,
#  'I_8NNCTX7tzwJA53byZ2lQ': -0.3022,
#  'RwxU6hhZUZIB-gdm5sOmvA': 0.4002,
#  'QnB24kLHmSNIaKSWr7JMLg': 0.3279,
#  'sQD_UmlGXwhtsBKgePOGwA': 0.0884,
#  '-g_ZoyofUWExZJoTFpKqJw': 0.1653,
#  'rHxc9sR5ELjboLqd_fUzJg': 0.9119,
#  '8mtT2u4PuZycYPVtKvYKhA': -0.0945,
#  '1YNONDlsPqeV26qWPfigjg': 0.4308,
#  'dXkdDN6iKY7eJG6UY_KCBw': 0.4042,
#  'vwxH_-B2AdXem3iUE_7QrQ': -0.3083,
#  'na7WphTb_6wXqVpusiXY9w': 0.4339,
#  'LkwE0gH_tb8dNPrDpnPfGQ': -0.5423,
#  'J6sKx_lEaWR5-gk0gxZfaw': 0.5978,
#  'R_d7wnPYsAFOt4kE_imzOQ': 0.0253,
#  'A4t1UT6j1lSQN6OM0Oy2GA': 0.0034,
#  'VVQS2pgCj9BLzB2kLIwdWg': 0.3515,
#  'SB1bzTva7pHbSLHz69xh6Q': 0.0,
#  'bw6XmtvLEmdd2OjE8SVnIg': -0.1609,
#  'kK-rmiHVtxhyV74im9zPTQ': 0.3344,
#  'J_Frd5Z3YxcmEp2E1JB8yA': -0.134,
#  'Dgzrb9DTWozUcYOe4L9_FQ': 0.397,
#  'WNnkyVvBfY1vTqiqSufZQA': 0.1527,
#  'ceP48LDxQCYMnDu9hOwXqw': 0.3066,
#  'OmWCWwgLsVZlWAbxmYkH1Q': 0.6458,
#  '7jEs2CVAKu6AhTGi0DvCLA': -0.8567,
#  'tIeIgzEr1hap9rXDlSnw_A': 0.7883,
#  '3dcOfKP4hhmITUur6TixAw': -0.2375,
#  '3IJ4jO6XN9_vzQUs6eXQqQ': 0.0733,
#  'uNPIS249cVX9YxiG_wNWKg': 0.2077,
#  'RSs4HXkHR9_960k3F_txZA': 0.9905,
#  '-7F3BVqvfVAKeqUj_9WPBA': 0.6564,
#  'GVphlD0JMbfIzRThjqNngA': 0.0934,
#  '7kVFRn-mYM36OBOrD_vyNw': 0.3301,
#  'd1822LP9oDx2-AsVL9z7Ww': 0.4635,
#  '6Cm083HMNeyh3o_95ePr_A': 0.7758,
#  'AycqWXrDVlbRfJE-kA5MMw': 0.8836,
#  'kWqMFvhdip9s4N9o68NNgg': 0.742,
#  'cs_3GebpYdsU9BDYUtxkiw': 0.3801,
#  '6_-T_TQOU-DlzEW3aSZJkQ': -0.0212,
#  'YrqQWT5wzBUumklE4B_XfA': 0.2371,
#  'lzaRuySciop_lWcWEOxO9Q': 0.2151,
#  '-CJ_Hlfmw6Fyp2_MhSi8kw': -0.0063,
#  'A7v3yvvh9VTVbt0nTEUDfA': 0.6105,
#  'tnZpIRV9cvhllwAP17dRQA': -0.5267,
#  'NLnci3vWOqGAHA_bdwQdww': -0.2471,
#  'Y7vxWyd0jYA3DFk4J6rMrg': 0.2556,
#  'sZmeE5c132fxmSXOSeqouQ': 0.6924,
#  'ifoRVp-v_m9S_C8uK-_8yA': 0.4433,
#  'p5EcPXmrWyWOzib1YF_4Hg': 0.4262,
#  'qFH9UDl2038qsxgrUqLiqQ': -0.2685,
#  'qa3ebjk50Lf9WctS76uv7Q': -0.5389,
#  'y-OgJRZPONTuMeNYuXN3qg': 0.0988,
#  'UIsg_IHBQwpIKg7ZWWqMdg': 0.5984,
#  '6nan60uLC6yQqE5QUkO3qA': 0.7227,
#  'vGy4A42_1o8ZISqG4FrKfg': 0.1574,
#  'S9uMR0DK2jgdyxrFYiGVpQ': -0.0105,
#  'XvyR6ZxW2_93IqWRzHwwDQ': 0.2323,
#  '28cvky6Yt_Qpk4Zj49FN_g': 0.5451,
#  'XpARiMDzZLbUWslHzr-NFg': 0.0225,
#  'JK6z2bNZYnRd958Fjj7bEQ': 0.2324,
#  'm1_h6ju-MaGsH1TQEVZKHA': 0.1749,
#  'bTvIo9DIcdgNe_EQHGYSZg': 0.4765,
#  '7a7oDxji_tnU6Gb-MoI6fA': 0.9819,
#  'b-CA7-xFUIrwG7MKwGw70A': -0.1515,
#  'Pet7cc5_iOJevw98MGOJag': 0.1643,
#  'eZG3ldsHielH2FZDqEFuEg': 0.1084,
#  '-MuW_FZPZOIbf9rwsT_Gyg': 0.1027,
#  'uH36B406UyC7s6y_-yfOgQ': 0.2509,
#  'GrHRFIQIcZzQH172M0L_YA': -0.3519,
#  'p6SiabNKHKSSC_4d6aBEKw': 0.6071,
#  'crx0qEGxeHO2Jm1fV1yA9A': 0.0745,
#  '5Rcj46cULbk38xI28ATX_Q': 0.1944,
#  'tZsSTf4Q7eoq4v0-_HvPPg': -0.4092,
#  'AQd0cKb8cVTn8ksq7XySJw': -0.223,
#  'H4-PU2SIOfHgi3R1hCC0-g': 0.4072,
#  '-3Yo-5oNDhJ3SFgCGfOyuw': -0.0093,
#  'V2MhYJSV9dXQOtqzoZr5vA': 0.1781,
#  'uKcVJ3OqtrzM-3Yd-Y32nQ': 0.4578,
#  'wZhB4U003eg2GQ-F7D2D4A': 0.2629,
#  '8cFzTMz32V8d8VWoAKpocw': -0.0754,
#  'XbooiPex1pWSy_pfPlavnQ': 0.2889,
#  'qcDFrv2EQU9GeIAAVqdA-g': 0.1747,
#  'aKGnuINAtyP32v3Hl23j3Q': 0.4063,
#  'BglON-uxLAXHgnC5amGscA': 0.4051,
#  '8M09hd8fd44NlX8KVHricg': 0.375,
#  'lEjbQgb77t6uVQTM3K6YSg': 0.1616,
#  'TrLLR-9O35aqZoz5ozVm8g': 0.2748,
#  'MKs7SRn93EaA6c3D6xv0Kw': -0.0752,
#  'LLikt486stSxz5ZA168pdg': -0.4531,
#  '7fgi8nvXjjiTOwuVdd1oSw': 0.7015,
#  'BXgfD10M9MDESEUom_D-bw': 0.4478,
#  'wCtbZqjWBI5dOCrvVQQKXA': 0.24,
#  'HD_T8ILGSAmqoUYVIgq5_Q': 0.2073,
#  'yEgn5ocDAtdXrkrD1UaLLA': 0.3065,
#  'rln7MG7Oho5fH5aQ1i_v5w': 0.1646,
#  't6UwQ45hbHw-X7A7Yrc_ag': 0.035,
#  'GqFCZvsb4xKc27juBo_78w': 0.3696,
#  'rMJL7CeUWJjPCxpSaqbF2g': 0.1711,
#  'x4KHNdgeaZuF0y8EwWZhnw': 0.5514,
#  'tmn9Ccyhg9AjZMjNUJZacw': 0.4146,
#  'c163MT4vFQD5PEIfoHZLxA': 0.6351,
#  '8JZFVGmRyps3JSOGO866-A': 0.0159,
#  'Mq_aLBdYZoxNysghdT6bGg': 0.3511,
#  'XZV6pSuJkfsyoT9eJc3dWw': -0.1941,
#  'en4dhG7NjjvFC4OdQXxkxQ': 0.344,
#  'zLLWRSnSZWIk5fD95COm0A': 0.5273,
#  'Qqu_MRaus17-4VVmzXq1_g': 0.4701,
#  'XLmI1a3JDthshMYA9Qbrkw': 0.4582,
#  'A50PH9S0v8bP02X8RjrseQ': -0.0912,
#  'LtPyB3XcPUqrXAJ4qK9o0g': 0.3928,
#  'MVX2dIuLwjaQ3d033-J8bQ': -0.0129,
#  '2ULqorHLdQE6hep9eDi8lA': 0.3974,
#  'BFxKbF8jWBGArdWfXPMBrw': -0.1621,
#  'TgcjQfl1E9DE-SjDVOUDJQ': 0.5229,
#  'vw-nWZ9D1XBjclpTXvg7QQ': 0.3626,
#  'KkSLvNRkf1LfK4Dta2sctQ': 0.3204,
#  'uLyeGUKKi_hDlnhEEqsDPA': 0.2621,
#  'VCab4G-uXVdn2hyV3ZlFEw': 0.2997,
#  'AjNpzeNPSsul2ZdZHWaiwQ': 0.4347,
#  'Tol3SFEtO-fOUHbFdSPeew': 0.105,
#  'R9bFr7dADF2fosWJjgbyWQ': 0.4754,
#  'Xe940JO_nqj5vLSd9UBQCQ': -0.1039,
#  'XtJbDZODXi3mXHLoScGtwg': 0.5678,
#  '2tR9tzJd_D1QCaNUVj977A': 0.0883,
#  'DGkjLTH7BiHp_sMgUExYCQ': 0.0148,
#  'R0-FICdwMhsY_uYEWZDZeA': 0.367,
#  'dmg1WD9FPMnT256qrjnO3A': 0.1191,
#  'nNho3XrlAaYSjeHoZ6Y07g': -0.178,
#  '17mLQqwh6EsmX7VoU8gHnQ': -0.0439,
#  '1qOxjcR4x8JzLFjRX0rvXw': 0.2485,
#  'HfvnvPWbhMqtVVRlG1s41w': 0.1414,
#  'g7gt12BsNFA0nHjsDkT4sg': 0.7485,
#  'hQt0N0vrjAjGQ2DVdgVGGQ': 0.2162,
#  'jR9GbFc7kDegrKmKLCeQqQ': -0.3181,
#  'gh0mBl_SBZ6kX9mYMq-R5g': 0.4773,
#  'JbERlUxFVyqayc-QcZQX-Q': 0.408,
#  'mUtywQ-Kx9rPB5d94Fi1gQ': 0.4478,
#  'Lizo6IblIaAUqwIMjtimEA': 0.3504,
#  'DE89UdHFMCN6DtYWZuer5A': 0.198,
#  'CWkd_PmKOGjJuP1hxxjV3Q': -0.2162,
#  'yUlekeb1lOnBC8A-2zzpow': 0.069,
#  'Ep2gJuOUW13YE8ufv-KaZA': 0.5326,
#  'p6mnPa2-__9ttPTIfecc0Q': -0.1837,
#  '-Xez48vsHLB59cYbKyi91g': 0.9556,
#  'lh2ezG3kYADZ_y9qe8bkmg': 0.279,
#  'lfFV--1jAsnvynf6ZlJLBQ': -0.2455,
#  '6BZ-yG31kf-zOaD8s-0_jA': 0.4778,
#  'HnbWx7Q8P4-MXbxMpb-qVw': 0.1747,
#  '6soO5TcIigL6DI44iSo3YA': 0.6406,
#  'MvqeYJeSxNcqgehnRBveUA': -0.0065,
#  '5sjJDU6EByxP8m_aIb-P7Q': -0.1231,
#  'yIv16u-qg-kkY20Fdho2Lg': 0.3927,
#  'wg74HAI3neOQYPxpqHZBpQ': -0.5806,
#  'mjU8pBh4T5EtFXBApIIEHg': -0.0832,
#  'hV_MuwIfuhHk62eQJUHTwA': 0.6345,
#  'Yi6Y7SHNp83dpVEBKhyfhQ': 0.3143,
#  'Z9aPsQIZXPSEuiKY2S3dDQ': 0.1235,
#  'VfOH8xKDked6ogNNya37GQ': 0.1741,
#  'u5M9HsBJa2rzzu1X1Lex7Q': 0.3248,
#  'um-3muZ0K6LHIYGt1w9oaQ': 0.3213,
#  'jcquiFyi5LA1bFNsuCt7Cg': 0.0796,
#  'xKG71Oh_ZgH7YNTrxOgdRw': 0.049,
#  'Rp9gsthQjYKkZenRMWmQag': 0.2889,
#  'O-uIEuv7JLUHajkemx_sVw': 0.6157,
#  'wWBTu52XgIRfXhw5l9V1Uw': -0.0311,
#  '-l-NU9pFkIW7TOGdJN3hFw': -0.5741,
#  't8FmkV-AWZfmidXzkLegqA': 0.3235,
#  'dSXoJJqzNPyE7j-st_otxA': 0.2848,
#  'nV8mDMin6c964MgjK6JZgg': 0.0363,
#  'Omc0l15umc8_Q4F4I1ERjQ': -0.1066,
#  '1Gkc4mwdpzdHTRG9bZcI5w': -0.9224,
#  'NUHNLaMg7aMesMdAiie73w': 0.005,
#  'xeDfJXCaTYR4YtFl8oXtCQ': 0.9016,
#  'yuRnph5nTK9OhQWHrliqiA': 0.4575,
#  'Kpk1wm96lLQV3gJWNumfbg': 0.6672,
#  'wKrnJ8AYAix5lJCtnpT8fA': 0.2726,
#  'm34S3rkKc2v9zCohTPi6bQ': -0.0892,
#  'v1xtfFAyJfUS_Lym8tvJ8g': 0.5354,
#  '6sZH6GbpnnyUs9_cXe_x7w': 0.3019,
#  'kL9Kh_cBGy7ky3OVclCnDA': -0.4555,
#  '-CFy3XMNMU7u_TSeKo2PQA': 0.0706,
#  'POSecN4gvo8hwWufmOWOsw': 0.0641,
#  'wjqOdj0XJUDOOtU9LjRlWQ': 0.5165,
#  'KUdj08tVC3tvIT0rM6V8uQ': 0.3587,
#  'hrwaO1X9MJYyelOzGdZdpA': 0.1063,
#  '4SNYBFQP-KegHX1k-pCmaw': 0.129,
#  'c-j9MfyxwxPMq5M2lVJcIw': 0.5265,
#  'RGjNIP6LvJNsy51IcKXj3w': -0.1183,
#  'pn3Jsn6VE06MaK6JuQ3f0g': -0.0647,
#  'HovWrpnDQ5Ii4nbhCK1v-w': 0.1146,
#  'I8KkogiDbY2qFLiCVFn_Jw': 0.5801,
#  'FAdJLp0gxVQHEKc7-6Wqag': 0.1117,
#  'AAMGbJ2Rw6L165eWpr65Uw': 0.0472,
#  'haeyExjSiJNENQKTxTmiPQ': 0.1771,
#  'BUjeyD8W-fAsyU-u8g2dcA': 0.7356,
#  'E6Eb8Xp8HfzYLVudLQO2FA': 0.9605,
#  'QEsUAatQyuLFvTwrl6s6iQ': 0.0799,
#  'lKLTkDg1pbHxCzIoFpPZGg': 0.0686,
#  'ze1GHqt8ZVRIBQdKjO4tpA': -0.0928,
#  '5bvmJHphkYPRkz_70S8YBw': 0.1112,
#  'jRRC_tlEgOmDIhnB2qN2uQ': 0.3268,
#  'VF6al3kAVLMtXNnscPJahA': 0.1818,
#  'JyNs3ATYz0IntVB0a1tGPA': -0.1201,
#  '5HO0ze-6yLb4_S49q54yXQ': 0.2193,
#  'TibTrHAfWQwTKRIdIy1kSg': 0.5491,
#  'JJmQzz_YfUK62bcdzBi01A': 0.3459,
#  'dr57Gr2FeEGL7xSutbGSaQ': 0.0166,
#  'edBF6KmAzMvX6-nJUPVUsw': 0.2426,
#  'lDkKSL4AT2faZwClvCvLnw': -0.6908,
#  'D983mWf0EZet6f5rghzgsg': 0.2738,
#  'DNBw7OLTK9SK0DLAujf_xg': 0.2232,
#  'w9A-X6UBotS1q2nOpKvbyw': 0.3443,
#  'PwO3JDkkY6y9Jty8aXFmsQ': -0.0264,
#  'aTDFpSBWNEssyTme6Dlq5w': 0.1583,
#  'hhQn9GA67e5wi7Bg2TWvYw': 0.0262,
#  'c4OOIp8iYf6_CtFxggA0vg': 0.1258,
#  'A2z1Y0WOh_03BBCfLnzXuA': 0.0324,
#  'EhWdILkqEmz0XNO46LXXdw': -0.0016,
#  'fY-Q8rUydkQCyf5tUbveAA': -0.1142,
#  'bzQr_Qbn127SpEZPCT2IZA': 0.3502,
#  'b93xrI79H_GDaxR4gMZwMg': 0.2233,
#  'naPjNkvj5EOR7WovBWF-zw': 0.5712,
#  'Da7mSOGmg0crIWTovNcZVA': -0.063,
#  'LPGXfFw6H-fEGI4Yxx679w': 0.891,
#  'ZApipKqs2SnlyrsB4u0oaw': 0.083,
#  'uRSndONED0kmRnw0LRrD-A': 0.9057,
#  'BtJ9DVs6fDEzU8ZTFYv39g': 0.9246,
#  'KkRmW-2ckg8-4BQEx_9lVA': 0.891,
#  'mWeuHfvd90UcKjCk71O-SQ': 0.1115,
#  'RfpTnKN2uTMazhNmDttQFg': 0.4617,
#  'MNIIRlWXotubOauSksv9AQ': 0.1804,
#  'RLupiPA5rOYx3NCW-vXsig': 0.185,
#  'UeK6rFgkd9pylPi6p51ZVw': 0.2858,
#  'nz-4Uv4kA2kclzkS5wV78Q': 0.6249,
#  'BK8EX7eAO5dA9yzV7el3yg': 0.6882,
#  '7pS-sR7UvJZ56NPwtBVYnA': 0.654,
#  '9pp4WAPcvgwA_3FsHmMXBA': 0.5624,
#  'OwcfAtj2JUgzWpYl0sfY1A': 0.81,
#  '_CYxRKguIjac-OFBvSqehg': 0.9099,
#  'wsbz9UDvW_fo4sPMuKqpvg': 0.8176,
#  'J6-VBRrhHImiMHLpIwG7zA': 0.8622,
#  'WKcVegcUjAld1S737a_QHw': 0.5142,
#  'pL5S3eXO4j7jrKigOdpQ0A': 0.5673,
#  '-r2ksehD5amap-pISjzYJg': -0.0696,
#  'COExayvsDDJOjWTOFZ7a4A': 0.2675,
#  'HG6flD74PQf7uSvuKrDIXg': -0.085,
#  'ptgQXfZMXSXx4wvf-qv0vg': 0.4116,
#  'WoLGuuAdU1W-0eMgKVm8Dw': 0.5128,
#  'XIQZC49qv_75_3sKQApSsw': 0.5071,
#  'ybDjlBqNunBZcUYl2x4FsQ': 0.4652,
#  'dROpdh6_n37Knlc661_3Uw': 0.545,
#  'BxkAcsey9JkN6qtgEgdzgw': -0.0719,
#  '8CcmHGUGlEEF2eNvS3ndMg': -0.1635,
#  '5-KisjcYyWN6Fwcp-wDYmw': 0.2519,
#  'HM5_OwVGW4YEHgyOf56IAQ': 0.4649,
#  'JTaO4i-a1wy969fkf7fFRw': -0.7275,
#  '93CpB87DiFtK8TbBiD77AQ': 0.6807,
#  'cEW1BiNLPAel0flu9SQluQ': 0.4465,
#  'xaqW4NkmUCGRRjmLxiFJ6Q': 0.4168,
#  'nUNx-WGANZdNaJd3cqHTIQ': -0.1795,
#  'OOO4iaFaBffyeZjiffJccA': 0.4244,
#  '8YShjSATcrSpenlDUnHh-g': -0.1095,
#  ...}
